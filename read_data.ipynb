# %%
from src.preprocessor.utils.dataset_level import read_pickle

read_pickle('./data/processed/queries.pkl')
# Out:
# {'161615': 'Người học ngành quản lý khai thác công trình thủy lợi trình độ cao đẳng phải có khả năng học tập và nâng cao trình độ như thế nào?',
#  '80037': 'Nội dung lồng ghép vấn đề bình đẳng giới trong xây dựng văn bản quy phạm pháp luật được quy định thế nào?',
#  '124074': 'Sản phẩm phần mềm có được hưởng ưu đãi về thời gian miễn thuế, giảm thuế hay không? Nếu được thì trong vòng bao nhiêu năm?',
#  '146841': 'Điều kiện để giáo viên trong cơ sở giáo dục mầm non, tiểu học ngoài công lập bị ảnh hưởng bởi Covid-19 được hưởng chính sách hỗ trợ là gì?',
#  '6176': 'Nguyên tắc áp dụng phụ cấp ưu đãi nghề y tế thế nào?',
#  '88965': 'Chi phí hoạt động dịch vụ của Ngân hàng Hợp tác xã Việt Nam bao gồm những khoản chi nào?',
#  '65283': 'Người học ngành điện tàu thủy trình độ trung cấp sau khi tốt nghiệp có thể làm được những công việc nào?',
#  '60201': 'Hương ước có nội dung trái với phong tục tập quán của địa phương thì xử lý như thế nào?',
#  '103523': 'Luật sư nước ngoài đã được cấp Giấy phép hành nghề luật sư tại Việt Nam thì có thuộc diện cấp giấy phép lao động không?',
#  '151281': 'Xe ô tô chở rau cho gia đình có bắt buộc phải lắp thiết bị giám sát hành trình hay không?',
#  '40958': 'Chính sách rủi ro của công ty chứng khoán do ai phê duyệt?',
#  '3426': 'Điều kiện để rút ngắn thời gian thử thách của án treo là gì?',
#  '136306': 'Trách nhiệm của cơ quan quản lý nhà nước về bình đẳng giới đối với việc lồng ghép vấn đề bình đẳng giới trong xây dựng văn bản quy phạm pháp luật được quy định thế nào?',
#  '81152': 'Tiêu chí để được công nhận là cơ sở công nghiệp quốc phòng là gì?',
#  '107281': 'Đơn vị được lựa chọn thực hiện huấn luyện, bồi dưỡng nghiệp vụ kiểm định kỹ thuật an toàn lao động phải đảm bảo yêu cầu gì?',
#  '43459': 'Mức đóng bảo hiểm xã hội tự nguyện hiện nay được quy định như thế nào?',
#  '162877': 'Bột cánh cẳng bàn tay người thực hiện chuẩn bị phương tiện như thế nào?',
#  '38529': 'Khi thực hiện tiêm chủng chống dịch có phải báo cáo hằng ngày không?',
#  '85400': 'Nhân sự vận hành, quản trị hệ thống, bảo vệ an ninh mạng đối với hệ thống thông tin quan trọng về an ninh quốc gia phải đáp ứng điều kiện gì?',
#  '84391': 'Trình tự, thủ tục cung cấp thông tin khách hàng cho cơ quan nhà nước của tổ chức tín dụng được quy định như thế nào?',
#  '100766': 'Bổ nhiệm viên chức giáo vụ trường trung học phổ thông chuyên đối với viên chức đang làm công tác giáo vụ nhưng chưa được bổ nhiệm theo quy định cũ khi nào?',
#  '29288': 'Điều tra viên của cơ quan điều tra chịu trách nhiệm trước cơ quan nào về quyết định của mình?',
#  '139159': 'Thủ tục nhập học đại học năm học 2023-2024 như thế nào?',
#  '95498': 'Trách nhiệm của các bên nếu vi phạm về đấu thầu dẫn đến hủy thầu?',
#  '5273': 'Người tham gia bảo hiểm y tế được hưởng trong phạm vi nào?',
#  '111705': 'Phó Cục trưởng Cục Thi hành án dân sự cấp tỉnh chịu trách nhiệm trước ai?',
#  '142272': 'Hồ sơ tuyển chọn Thẩm phán Tòa án nhân dân cấp huyện phải được giao lại cho Chánh án Tòa án nhân dân cấp tỉnh quản lý khi nào?',
#  '788': 'Công nhân quốc phòng bảo đảm kỹ thuật khí tài nước phải đáp ứng những tiêu chuẩn nào?',
#  '59835': 'Tài sản cố định vô hình tại cơ quan nhà nước, đơn vị sự nghiệp công lập không phải tính hao mòn đúng không?',
#  '119725': 'Ủy ban nhân dân cấp tỉnh quyết định giá đất cụ thể dựa vào các căn cứ nào?',
#  '19803': 'Vận chuyển trái phép 100kg pháo hoa nổ bị xử lý trách nhiệm hình sự như thế nào?',
#  '20930': 'Xác định cha mẹ cho con được pháp luật quy định như thế nào?',
#  '105518': 'Tổ chức phát hành xuất bản phẩm nước ngoài có phải nộp lệ phí khi thực hiện điều chỉnh thông tin trong giấy phép thành lập văn phòng đại diện tại Việt Nam?',
#  '2634': 'Đã hết thời hiệu xử phạt vi phạm hành chính thì có thể ra quyết định xử phạt vi phạm hành chính không?',
#  '103459': 'Công an viên mất trong lúc làm nhiệm vụ thì được hưởng chế độ gì?',
#  '126541': 'Công chức đang quản lý tài liệu bí mật Nhà nước được quyền quyết định tiêu hủy tài liệu bí mật Nhà nước khi nào?',
#  '72016': 'Kiểm định viên chất lượng giáo dục nghề nghiệp phải có kinh nghiệm trong những lĩnh vực gì?',
#  '60701': 'Bố trí kinh phí từ ngân sách nhà nước; huy động các nguồn lực của tổ chức, cá nhân để thăm, tặng quà Trung thu cho trẻ em đúng không?',
#  '118499': 'Giáo viên trường trung học cơ sở có những nhiệm vụ gì trong quá trình giảng dạy?',
#  '117044': 'Hội đồng thi đánh giá năng lực tiếng Việt theo Khung năng lực tiếng Việt dùng cho người nước ngoài có nhiệm vụ gì?',
#  '99994': 'Khai thác quỹ đất để tạo vốn phát triển tài sản kết cấu hạ tầng giao thông đường bộ được quy định thế nào?',
#  '136995': 'Thu thập, cung cấp và cập nhật thông tin, tài liệu vào Cơ sở dữ liệu quốc gia về dân cư thì cơ quan, tổ chức, cá nhân thực hiện có trách nhiệm gì?',
#  '136300': 'Thời điểm đánh giá và xếp loại chất lượng hằng năm của công chức, viên chức thuộc Bộ Tài chính được diễn ra trong thời gian nào?',
#  '12179': 'Truy cứu trách nhiệm hình sự đối với hành vi ngược đãi cha mẹ của con cái như thế nào?',
#  '26285': 'Công ty cổ phần có thể đưa chi phí mua xe của Giám đốc vào chi phí khi xác định thu nhập chịu thuế thu nhập doanh nghiệp được không?',
#  '66275': 'Số lượng thành viên Hội đồng khoa học và đào tạo là bao nhiêu?',
#  '58643': 'Về chi phí tiền lương, chi phí nhân công trong giá, đơn giá sản phẩm, dịch vụ công xác định tiền lương của lao động quản lý doanh nghiệp dựa vào đâu?',
#  '120259': 'Hồ sơ trình thẩm định, phê duyệt kết quả kiểm định an toàn đập, hồ chứa thủy lợi bao gồm những gì?',
#  '133838': 'Cơ sở cho thuê nhà trọ có phải đăng ký kinh doanh không?',
#  '124263': 'Trả lời thỉnh thị như thế nào trong trường hợp nội dung thỉnh thị liên quan đến các đơn vị ngoài ngành Kiểm sát?',
#  '83167': 'Hành vi làm tiền giả sẽ bị xử lý như thế nào?',
#  '103402': 'Nước ngọt có ga và nước tăng lực do nhà sản xuất tự công bố sản phẩm hay phải đăng ký công bố sản phẩm?',
#  '41212': 'Những trường hợp chấm dứt hợp đồng lao động theo quy định hiện nay?',
#  '76152': 'Điều kiện đối với người chịu trách nhiệm chuyên môn về quầy thuốc, nhà thuốc được quy định như thế nào?',
#  '91215': 'Việc ghi nhãn sản phẩm giấm lên men phải được thực hiện như thế nào theo quy định?',
#  '61027': 'Ban Tài chính Văn phòng Kiểm toán nhà nước thực hiện những chức năng gì?',
#  '85992': 'Người nước ngoài có được xét tặng Giải thưởng Hồ Chí Minh về khoa học và công nghệ hay không?',
#  '103578': 'Hội viên chính thức của Liên đoàn Thể dục Việt Nam có những nghĩa vụ nào?',
#  '61773': 'Thành viên Hội đồng coi thi kỳ thi chọn học sinh giỏi quốc gia có trách nhiệm bảo mật như thế nào?',
#  '121478': 'Kiểm tra văn bản trước khi ký ban hành văn bản như thế nào?',
#  '90029': 'Có thể khởi kiện ra Tòa án để đòi lại giấy đăng ký xe máy không?',
#  '64562': 'Xóa dữ liệu camera về hành vi đánh đập người khác là che giấu tội phạm hay đồng phạm theo quy định của Bộ luật Hình sự?',
#  '107630': 'Tập trung phát triển xã hội số trong xây dựng nông thôn mới trong chương trình chuyển đổi số trong xây dựng nông thôn mới, hướng tới nông thôn mới thông minh giai đoạn 2021 – 2025?',
#  '133442': 'Vụ trưởng Vụ Công chức Viên chức do ai có thẩm quyền bổ nhiệm?',
#  '31280': 'Số lượng sĩ quan có cấp bậc hàm Thượng tướng trong biên chế Công an nhân dân là bao nhiêu người?',
#  '33441': 'Hồ sơ, thủ tục đề nghị cấp giấy xác nhận giải mã phiên hiệu, ký hiệu, thời gian, địa bàn hoạt động của đơn vị Quân đội?',
#  '84425': 'Công ty sử dụng người lao động đã đến tuổi nghỉ hưu làm công việc độc hại, nặng nhọc trái luật bị phạt bao nhiêu?',
#  '143317': 'Chủ sở hữu nhà nước đối với Tổng công ty Lương thực miền Bắc có quyền hạn gì?',
#  '25008': 'Hạn nộp tờ khai thuế trong tháng 8/2023 và tháng 9/2023 là khi nào?',
#  '5066': 'Hợp đồng bao gồm những loại chủ yếu nào?',
#  '105339': 'Khi thực hiện điều chỉnh, sửa chữa sổ kế toán thì có được tẩy xóa các thông tin đã ghi sai trước đây không?',
#  '55168': 'Nộp đơn đề nghị phúc khảo thi tốt nghiệp THPT năm 2023 tại đâu?',
#  '152667': 'Người học ngành lái tàu đường sắt trình độ trung cấp muốn tốt nghiệp phải hoàn thành tối thiểu bao nhiêu tín chỉ?',
#  '7102': 'Quy định của pháp luật hiện hành về chiếu phim lưu động, phát sóng phim trên hệ thống truyền hình?',
#  '19163': 'Đề xuất quy trình xét tặng Giải thưởng Hồ Chí Minh và Giải thưởng Nhà nước cấp Nhà nước như thế nào?',
#  '146200': 'Nếu muốn áp dụng giá hợp đồng trọn gói đối với hợp đồng tư vấn khảo sát xây dựng thì phải đáp ứng được những điều kiện nào?',
#  '165046': 'Có được rút bảo hiểm xã hội 1 lần ở công ty cũ khi đang đi làm ở công ty mới không?',
#  '98564': 'Có dùng phụ cấp trách nhiệm theo nghề áp dụng đối với Thẩm tra viên chính để tính đóng bảo hiểm xã hội tự nguyện không?',
#  '62743': 'Để lập quỹ đóng thì cần phải chuẩn bị những giấy tờ gì cho hồ sơ đăng ký?',
#  '1397': 'Nhiệm vụ của giáo viên được quy định như thế nào?',
#  '25875': 'Kế toán trưởng của chi nhánh doanh nghiệp nước ngoài hoạt động tại Việt Nam có trách nhiệm như thế nào?',
#  '116997': 'Cơ quan nào có quyền quyết định việc thu hồi chứng thư số của cá nhân thuộc phạm vi quản lý của Bộ Quốc phòng?',
#  '153980': 'Phẫu thuật lấy thể thủy tinh ngoài bao do ai thực hiện?',
#  '98099': 'Cục trưởng Cục Thuế doanh nghiệp lớn thuộc Tổng cục Thuế chịu trách nhiệm trước ai?',
#  '95399': 'Có thể đăng ký quyền sở hữu trí tuệ đối với tài sản chưa hình thành hay không?',
#  '34158': 'Tổng Biên tập cần tổ chức thảo luận tập thể lãnh đạo Tạp chí Kiểm sát trước khi quyết định những công việc nào?',
#  '121393': 'Ký hợp đồng dịch vụ làm việc từ xa với người nước ngoài được hay không?',
#  '22635': 'Doanh nghiệp viễn thông không gia hạn chứng thư số của thuê bao khi nhận được yêu cầu gia hạn thì bị xử phạt thế nào?',
#  '115757': 'Người làm công tác giao liên giai đoạn 1965-1975 2 năm được hưởng trợ cấp một lần và trợ cấp hằng tháng như thế nào?',
#  '45007': 'Dự án hợp tác pháp luật thuộc thẩm quyền phê duyệt của Thủ tướng Chính phủ được thẩm định theo quy trình thế nào?',
#  '103128': 'Phạm vi hoạt động trong lĩnh vực được cấp giấy phép hoạt động điện lực được quy định như thế nào?',
#  '91272': 'Nguyên tắc lựa chọn bao bì, dụng cụ, thiết bị lưu chứa rác thải của người mắc Covid-19',
#  '455': 'Việc tự đánh giá kết quả thực hiện nhiệm vụ khoa học và công nghệ cấp quốc gia về chương trình hỗ trợ doanh nghiệp phải đảm bảo yêu cầu gì?',
#  '30905': 'Thừa phát lại có cần phải tham gia bồi dưỡng nghiệp vụ hàng năm hay không?',
#  '25744': 'Các nguyên tắc về tốc độ và khoảng cách phải chấp hành khi điều khiển phương tiện trên đường bộ?',
#  '2129': 'Để thực hiện đổi tên quỹ thì quỹ từ thiện phải đáp ứng được những điều kiện nào?',
#  '100894': 'Khi sản phẩm thay đổi ảnh hưởng đến việc đánh giá kiểu loại sản phẩm thì cơ sở sản xuất máy đóng cọc cần nộp bổ sung những tài liệu nào cho Cục Đăng kiểm Việt Nam?',
#  '8326': 'Điều kiện để người nước ngoài được sở hữu nhà ở tại Việt Nam',
#  '137507': 'Người học ngành công nghệ sản xuất bột giấy và giấy trình độ trung cấp phải có mức độ tự chủ và trách nhiệm như thế nào?',
#  '32485': 'Điều kiện để Giám đốc Học viện An ninh nhân dân được thăng cấp bậc hàm trước thời hạn như thế nào?',
#  '50499': 'Trường hợp thành viên là cá nhân chết thì người thừa kế của thành viên đó có thể trở thành thành viên của công ty hay không?',
#  '29748': 'Trong quá trình khám bệnh, chữa bệnh ghi chép việc kết hợp y học cổ truyền với y học hiện đại như thế nào?',
#  '82256': 'Quân nhân dự bị đang trong thời gian tập trung huấn luyện thì gia đình có được hưởng trợ cấp gì không?',
#  '15851': 'Quyết định truy tố bị can trong vụ án hình sự sẽ được gửi cho những ai?',
#  '94628': 'Thời gian làm căn cứ tính hưởng chế độ tai nạn lao động nếu không liên tục thì có được cộng dồn không?',
#  '93476': 'Nam, nữ bao nhiêu tuổi thì được kết hôn?',
#  '15309': 'Mức tiền thưởng của danh hiệu Đơn vị tiên tiến là bao nhiêu?',
#  '83173': 'Tổ chức bồi dưỡng cán bộ trong các cơ quan nhà nước theo loại hình nào?',
#  '144572': 'Chế độ tiền ăn của Dân quân tự vệ như thế nào?',
#  '11636': 'Mức phí thẩm định đối với dự án đầu tư xây dựng điều chỉnh được xác định ra sao?',
#  '25168': 'Thực hiện thủ tục đăng ký hoạt động bán hàng đa cấp tại địa phương ở cơ quan nào?',
#  '142964': 'Tổng Cục trưởng Tổng cục Hải quan cần đáp ứng trình độ lý luận chính trị nào?',
#  '155888': 'Có anh trai tham gia thi thẩm định viên về giá thì có được tham gia tổ chức kỳ thi không?',
#  '33267': 'Chuyển tiền điện tử là gì?',
#  '55621': 'Nhiệm vụ của Hiệp hội Tư vấn Xây dựng Việt Nam được quy định thế nào?',
#  '154552': 'Văn bản ủy quyền giữa các bên có phải thực hiện công chứng hay không?',
#  '120684': 'Chủ tịch nước đã thôi giữ chức vụ thì có được tổ chức Lễ Quốc tang không?',
#  '145823': 'Doanh nghiệp tham gia xét chọn Giải thưởng Doanh nghiệp tiêu biểu vì người lao động cần đáp ứng được những điều kiện gì?',
#  '19655': 'Mức truy cứu trách nhiệm hình sự đối với người phạm tội tàng trữ trái phép vật liệu hạt nhân có tổ chức được quy định thế nào?',
#  '42623': 'Với các khoản học bổng được nhận từ ngân sách nhà nước thì có phải đóng thuế thu nhập cá nhân không?',
#  '139444': 'Những hành vi nào xâm phạm đến các quyền liên quan?',
#  '121235': 'Sau khi tiếp nhận thông tin về thông tin về vi phạm pháp luật hoặc dấu hiệu vi phạm pháp luật người đứng đầu cơ quan, đơn vị Quản lý thị trường có thẩm quyền cần làm gì?',
#  '145645': 'Ngoài lương được hưởng trong thời gian thi đấu huấn luyện viên và vận động viên còn được nhận những khoản nào khác?',
#  '83762': 'Bộ máy tổ chức của Trung tâm Phòng tránh và Giảm nhẹ thiên tai gồm những đơn vị nào?',
#  '116688': 'Khuyến mại rượu có độ cồn từ 15 độ trở lên sẽ bị xử phạt như thế nào?',
#  '162357': 'Cơ quan nào có thẩm quyền phê duyệt phương án phá dỡ tàu biển trên cơ sở đề nghị của cơ sở phá dỡ tàu biển?',
#  '11445': 'Nhiệm vụ của thống kê viên chính được quy định như thế nào?',
#  '56365': 'Quỹ Vì cuộc sống tươi đẹp được vận động quyên góp không?',
#  '52625': 'Ai có quyền quyết định số người làm việc trong Nhà xuất bản Tư pháp?',
#  '80193': 'Khuyến mại áp dụng cho những đối tượng nào?',
#  '32004': 'Ủy ban nhân dân tỉnh có phải là chính quyền địa phương ở tỉnh hay không?',
#  '109797': 'Đơn vị sự nghiệp công lập có được đơn phương chấm dứt hợp đồng với viên chức nữ đang nuôi con dưới 36 tháng tuổi khi từ chối đi biệt phái không?',
#  '45854': 'Điều kiện để trở thành một cổ đông sáng lập là gì?',
#  '124704': 'Thời gian giải quyết đề nghị thôi giữ chức vụ đối với công chức, viên chức diện Ban Cán sự đảng Ngân hàng nhà nước không còn đủ sức khỏe đảm nhiệm chức vụ là bao lâu?',
#  '146647': 'Trường hợp nào các vật thể thuộc diện kiểm dịch thực vật được miễn phân tích nguy cơ dịch hại?',
#  '48716': 'Bản Kết quả tự kiểm tra chất lượng dịch vụ viễn thông phải được lưu trữ trong thời hạn bao nhiêu năm?',
#  '148164': 'Đơn đề nghị đặt tiền để bảo đảm được tại ngoại của bị can được gửi đến đâu?',
#  '112647': 'Kiểm soát viên Bảo hiểm tiền gửi Việt Nam còn có những nhiệm vụ và quyền hạn gì?',
#  '44844': 'Cán bộ làm việc tại Trụ sở Bộ Tài nguyên và Môi trường phải có trách nhiệm như thế nào về việc giữ gìn vệ sinh tại nơi làm việc?',
#  '155088': 'Các thủ tục pháp lý được hỗ trợ cho phạm nhân chuẩn bị chấp hành xong án phạt tù thực hiện vào khoảng thời gian nào?',
#  '64487': 'Giáo viên dạy môn học Giáo dục quốc phòng và an ninh trong chương trình đào tạo trình độ trung cấp phải đạt trình độ chuẩn như thế nào?',
#  '97182': 'Chuẩn bị đánh giá chất lượng dịch vụ của tổ chức sự nghiệp công lập trong lĩnh vực khoa học và công nghệ như thế nào?',
#  '119644': 'Đối tượng nào không phải đóng học phí?',
#  '33713': 'Kho chứa LPG chai được lắp đặt, thiết kế như thế nào để đảm bảo an toàn?',
#  '67268': 'Thời hạn cấp thẻ căn cước công dân gắn chip là bao lâu?',
#  '60695': 'Các giấy tờ, tài liệu nào được miễn chứng nhận hợp pháp hóa lãnh sự?',
#  '37264': 'Doanh nghiệp dịch vụ đưa người lao động sang Đài Loan làm việc cần đáp ứng các điều kiện gì?',
#  '6985': 'Con dưới 18 tuổi có quyền có tài sản riêng? Ai là người quản lý tài sản riêng của con?',
#  '16780': 'Giáo viên trung học cơ sở được nghỉ phép vào thời gian nào trong một năm học?',
#  '30101': 'Con 10 tuổi có được xin thay đổi tên của mình hay không?',
#  '64326': 'Ai điều hành toàn bộ hoạt động của Trường Chính sách công và Phát triển nông thôn?',
#  '154780': 'Mua bảo hiểm y tế tại Thành phố Hồ Chí Minh về quê khám chữa bệnh ở bệnh viện tuyến huyện được không?',
#  '48371': 'Công ty cổ phần chào bán cổ phiếu ra công chúng phải cam kết bán được bao nhiêu cổ phiếu cho nhà đầu tư?',
#  '145118': 'Cơ quan, tổ chức, chức danh nhà nước nào được quyền sử dụng con dấu nổi?',
#  '121386': 'Hồ sơ đăng ký hoạt động liên kết đào tạo nghề nghiệp được quy định như thế nào theo pháp luật hiện hành?',
#  '119919': 'Khi tôm sú giống có dấu hiệu mắc bệnh đốm trắng thì phải lấy mẫu thử với số lượng là bao nhiêu?',
#  '59135': 'Khoảng cách từ đường cho xe chữa cháy đến họng tiếp nước vào nhà phải đảm bảo trong phạm vi bao nhiêu mét?',
#  '15886': 'Công chức muốn dự thi nâng ngạch lên ngạch kiểm lâm viên phải có thời gian giữ ngạch kiểm lâm viên trung cấp từ mấy năm trở lên?',
#  '57586': 'Chỉnh hình tật dính quay trụ trên bẩm sinh được chỉ định cho bệnh nhân nào?',
#  '89925': 'Khi gia hạn giấy phép lao động có cần giải trình nhu cầu sử dụng lao động nước ngoài lại không?',
#  '65741': 'Đối với đồ án quy hoạch chung về thiết kế đô thị thì phải thể hiện như thế nào?',
#  '72599': 'Tôn chỉ, mục đích của Liên đoàn Luật sư Việt Nam?',
#  '66205': 'Có được thay biển số xe đấu giá trúng vào chiếc xe đang có biển số xe cũ của mình không?',
#  '73773': 'Chủ tịch Ủy ban nhân dân cấp xã có thẩm quyền phạt tiền đối với hành vi điều khiển xe đạp điện lạng lách, đánh võng không?',
#  '51391': 'Điều kiện giao kết hợp đồng bảo hiểm nhân thọ cho trường hợp chết là gì?',
#  '58036': 'Nhiệm vụ của Trưởng Công an xã được quy định như thế nào?',
#  '98305': 'Kiểm sát viên được phân công giải quyết vụ án hình sự theo thủ tục tái thẩm phải tập trung kiểm sát các nội dung nào?',
#  '68013': 'Ai có quyền quyết định nâng lương cấp bậc hàm Đại tướng Công an nhân dân?',
#  '152798': 'Có giới hạn số lần viên chức hưởng lương ngân sách nhà nước được vay vốn hỗ trợ mua nhà ở thương mại không?',
#  '91373': 'Thành viên công ty trách nhiệm hữu hạn hai thành viên trở lên có được chuyển nhượng phần vốn góp của mình?',
#  '23166': 'Việc quảng cáo hoạt động kinh doanh casino khi chưa được cơ quan quản lý nhà nước có thẩm quyền cấp phép kinh doanh casino bị xử phạt thế nào?',
#  '5142': 'Hành vi tổ chức biên soạn giáo trình có nội dung định kiến giới có thể bị xử phạt như thế nào?',
#  '98789': 'Người thuộc nhiều diện ưu tiên khi thi tuyển viên chức thì được cộng tối đa bao nhiêu điểm?',
#  '12453': 'Được phép chuyển đổi hóa đơn điện tử sang hóa đơn giấy trong trường hợp nào?',
#  '61957': 'Chất liệu của biển số xe được quy định như thế nào?',
#  '72647': 'Việc bảo quản thuốc tại quầy thuốc tây tại cần đảm bảo những yêu cầu gì?',
#  '134683': 'Tuần tra theo dõi tình trạng cầu giao thông nông thôn thì phải ghi lại những gì?',
#  '91245': 'Chi phí thẩm định giá đất để xác định giá khởi điểm có nằm trong nội dung chi cho hoạt động đấu giá quyền sử dụng đất không?',
#  '138562': 'Thuốc như thế nào so với biệt dược gốc dù chưa có giấy đăng ký lưu hành thuốc tại Việt Nam vẫn được cấp phép nhập khẩu?',
#  '38753': 'Để xác định giá cước viễn thông thì cần tuân thủ những nguyên tắc gì? Việc xác định giá cước được dựa trên những căn cứ nào?',
#  '123003': 'Kiểm tra bí mật điều lệnh Công an nhân dân được hiểu là gì và được kiểm tra như thế nào theo quy định?',
#  '67128': 'Thế nào là di tích lịch sử?',
#  '84581': 'Chủ trương đầu tư dự án PPP được quyết định thông qua cơ quan nào?',
#  '117305': 'Việc cung ứng thuốc kháng HIV được quy định như thế nào?',
#  '20274': 'Bên nhận thầu có quyền thay đổi biện pháp thi công so với hợp đồng đã ký hay không?',
#  '53716': 'Người đại diện theo pháp luật của doanh nghiệp vắng mặt mà không ủy quyền cho người khác thì bị xử lý như thế nào?',
#  '7861': 'Tổ chức, cá nhân trong nước sáng lập ra giải thưởng về khoa học và công nghệ khi đặt tên cho giải thưởng đó cần đảm bảo những yêu cầu gì?',
#  '142952': 'Thủ tục kiểm tra và công nhận sử dụng thành thạo ngôn ngữ khác trong khám bệnh, chữa bệnh được pháp luật quy định như thế nào?',
#  '52884': 'Quy tắc bay trong khu vực bay phục vụ hàng không chung sẽ như thế nào?',
#  '140040': 'Nội dung số liệu, dữ liệu công trình cần thu thập để tính toán suất vốn đầu tư xây dựng gồm những gì?',
#  '164699': 'Có thể bán tài sản kết cấu hạ tầng giao thông đường bộ khi tài sản bị thu hồi nhưng còn nhu cầu sử dụng không?',
#  '6604': 'Lái xe buổi tối không bật đèn bị phạt như thế nào?',
#  '131186': 'Trình tự thủ tục thu hồi Giấy phép vận tải đường bộ quốc tế giữa Việt Nam và Trung Quốc được thực hiện ra sao?',
#  '135845': 'Quyền biểu quyết tại hội nghị tòa nhà chung cư được thực hiện như thế nào?',
#  '67039': 'Có được xử lý đơn tố cáo nặc danh khi không có thông tin người gửi không?',
#  '6321': 'Những cá nhân nào được Hội Khuyến học Việt Nam xem xét tặng Kỷ niệm chương Vì sự nghiệp khuyến học?',
#  '75639': 'Vườn quốc gia Cát Tiên có tư cách pháp nhân không?',
#  '100629': 'Tội cố ý gây thương tích hoặc gây tổn hại cho sức khỏe của người khác trong trạng thái tinh thần bị kích động mạnh được quy định thế nào?',
#  '165787': 'Nhân viên vẫn tiếp tục đi làm sau khi hết thời gian thử việc mà công ty chưa ký hợp đồng lao động có được tính là có hợp đồng lao động không?',
#  '130998': 'Phó Thủ tướng Chính phủ có được sử dụng thường xuyên một xe ô tô trong thời gian công tác không?',
#  '69612': 'Thế nào là ngoại hối?',
#  '8122': 'Trường hợp tổ chức không thực hiện việc giao nộp vũ khí, vật liệu nổ quân dụng, công cụ hỗ trợ khi bị thu hồi thì xử lý như thế nào?',
#  '68207': 'Khi thành viên Hội đồng Dân tộc của Quốc Hội vắng mặt trong phiên họp toàn thể thì phải xin phép ai?',
#  '56681': 'Trình tự cho thôi làm nhiệm vụ Đại biểu Quốc hội được thực hiện theo bao nhiêu bước?',
#  '45203': 'Trường hợp nào được ưu tiên xét tặng Kỷ niệm chương?',
#  '135774': 'Đơn vị chuẩn bị dự án PPP lập báo cáo nghiên cứu khả thi căn cứ vào đâu?',
#  '46583': 'Người làm chứng, người giám định, người phiên dịch trong tố tụng dân sự, tố tụng hành chính không có mặt theo giấy triệu tập của Tòa án thì có bị xử phạt không?',
#  '84682': 'Nghị quyết của Ban Chấp hành Hội được thông qua khi nào?',
#  '158368': 'Cấp hiệu của nhân viên Cảng vụ hàng không gắn ở vị trí nào?',
#  '208': 'Doanh nghiệp được áp dụng những chế độ ưu tiên nào khi thực hiện thủ tục hải quan?',
#  '126788': 'Thời gian thử thách đối với người được tha tù trước thời hạn có điều kiện được tính như thế nào?',
#  '128685': 'Trường hợp người lao động muốn gửi lại sổ bảo hiểm xã hội cho công ty giữ giùm thì có trái với quy định pháp luật không?',
#  '41093': 'Hồ sơ đề nghị công bố thông tin sản phẩm thức ăn bổ sung gồm những gì?',
#  '98005': 'Phạm vi hiệu lực của Giấy chứng nhận doanh nghiệp khoa học và công nghệ được quy định thế nào?',
#  '128976': 'Thang điểm chấm thầu để chọn chủ đầu tư thực hiện dự án cải tạo nhà chung cư được dựa trên những tiêu chí nào?',
#  '21655': 'Thời điểm tổ chức thực tập phương án chữa cháy được quy định thế nào?',
#  '54378': 'Kết quả đánh giá xếp loại chất lượng công chức của Bộ Khoa học và Công nghệ được lưu vào hồ sơ gồm những gì?',
#  '103099': 'Người học ngành thiết kế thời trang trình độ trung cấp sau khi tốt nghiệp có thể làm những công việc nào?',
#  '154151': 'Doanh nghiệp thẩm định giá và khách hàng thẩm định giá có mối quan hệ như thế nào thì không được thực hiện thẩm định giá?',
#  '62184': 'Thủ tục ủy thác tư pháp về dân sự ra nước ngoài được thực hiện thế nào?',
#  '123921': 'Căn cứ tính thuế khi chuyển nhượng phần vốn góp vào công ty trách nhiệm hữu hạn 2 thành viên ra sao?',
#  '31993': 'Chi nhánh của doanh nghiệp nước ngoài có bắt buộc phải có kế toán trưởng không?',
#  '164520': 'Các trường hợp nào được xem là trường hợp bất khả kháng để điều chỉnh hợp đồng xây dựng?',
#  '79000': 'Lái xe có chịu trách nhiệm bồi thường thiệt hại không khi đi thực hiện công việc cho chủ xe và gây tai nạn?',
#  '111100': 'Lãnh sự danh dự nước Việt Nam được thực hiện các hoạt động nghề nghiệp hoặc thương mại của cá nhân không?',
#  '91048': 'Trình tự cấp giấy phép tạm nhập tái xuất nguyên liệu làm thuốc là dược chất gây nghiện được thực hiện thế nào?',
#  '61383': 'Quốc hội ban hành nghị quyết để quy định những vấn đề gì?',
#  '103649': 'Để được đảm nhiệm chức danh Cục trưởng thuộc Tổng cục quản lý thị trường, phải có năng lực, chuyên môn nghiệp vụ thế nào?',
#  '49536': 'Tiền lương làm thêm giờ ngày Lễ Quốc khánh 2/9/2023 có phải chịu thuế thu nhập cá nhân hay không?',
#  '41652': 'Người học ngành thiết kế trang web trình độ trung cấp sau khi tốt nghiệp phải đạt được những kiến thức nào?',
#  '129445': 'Dòng lưu chuyển hành khách tại cửa khẩu đường hàng không được thực hiện thế nào?',
#  '15582': 'Trường hợp nào cho phép F0 tự điều trị tại nhà?',
#  '156357': 'Phẫu thuật cứng gối theo phương pháp JUDET sẽ do ai phẫu thuật?',
#  '118200': 'Tiếng anh chuyên ngành trong chương trình đào tạo ngành công nghệ kỹ thuật phần cứng máy tính trình độ trung cấp chuyên nghiệp có những nội dung nào?',
#  '143648': 'Không có công đoàn cơ sở thì có bắt buộc phải xây dựng thỏa ước lao động tập thể hay không?',
#  '111839': 'Người vay khoản vay nước ngoài được Chính phủ bảo lãnh muốn thay đổi khoản vay thì phải đăng ký thay đổi khoản vay với Ngân hàng Nhà nước đúng không?',
#  '34365': 'Tổ chức bảo hiểm tương hỗ trong lĩnh vực nông nghiệp, lâm nghiệp và ngư nghiệp dùng nguồn kinh phí nào để trích lập quỹ dự trữ bắt buộc?',
#  '61288': 'Mức phí, lệ phí khi thực hiện thủ tục cấp Giấy chứng nhận kiểm dịch động vật, sản phẩm động vật thủy sản xuất khẩu không dùng làm thực phẩm là bao nhiêu?',
#  '146618': 'Thành phần hồ sơ đăng ký hành nghề dịch vụ kế toán gồm những gì?',
#  '140891': 'Cơ quan nào giúp việc cho Hội đồng đánh giá trữ lượng khoáng sản quốc gia?',
#  '19301': 'Quốc hội cho phép trả lời chất vấn bằng văn bản trong trường hợp nào?',
#  '19161': 'Hồ sơ, trình tự thủ tục gia hạn thời gian lưu hành tại Việt Nam cho phương tiện của Trung Quốc được thực hiện ra sao?',
#  '124990': 'Các tiêu chí đo lường nghèo đa chiều cụ thể tại Việt Nam trong giai đoạn 2022 - 2025 là gì?',
#  '32112': 'Kinh phí từ nguồn ngân sách sự nghiệp khoa học và công nghệ Trung ương được quyết toán vào đâu?',
#  '4688': 'Thời hạn giải quyết cấp tài khoản định danh điện tử đối với công dân Việt Nam là bao lâu?',
#  '78956': 'Hội viên của Hội Hữu nghị Việt Nam và Trung Quốc có những nhiệm vụ nào?',
#  '157719': 'Tài liệu biên soạn bồi dưỡng đối với lãnh đạo, giảng viên được quy định như thế nào?',
#  '148195': 'Trong khi thực hiện nhiệm vụ bảo vệ Phó Chủ tịch nước thì chiến sĩ cảnh vệ có được huy động người và phương tiện không?',
#  '40303': 'Những sinh viên nào được miễn học giáo dục quốc phòng và an ninh?',
#  '104522': 'Doanh nghiệp Khu công nghệ cao là gì? Doanh nghiệp Khu công nghệ cao được phân loại như thế nào?',
#  '90450': 'Tài sản nào được dùng để góp vốn vào công ty trách nhiệm hữu hạn?',
#  '9198': 'Trong việc giám sát giao dịch chứng khoán thì những giao dịch nào được Sở giao dịch chứng khoán xem là bất thường?',
#  '136632': 'Phải có kinh nghiệm công tác bao lâu mới đủ điều kiện bổ nhiệm Vụ trưởng Vụ tổ chức cán bộ thuộc Bộ Tài nguyên và Môi trường?',
#  '162838': 'Chủ hộ khẩu có những quyền gì?',
#  '146740': 'Xử lý sự cố liên quan đến hoạt động của Phòng máy chủ của Ủy ban Dân tộc, đánh giá và phân loại mức độ ảnh hưởng của sự cố theo mấy mức?',
#  '10688': 'Chế độ thanh toán chi phí khám chữa bệnh đối với người tham gia BHYT 05 năm liên tục được quy định ra sao?',
#  '80762': 'Lực lượng Kiểm ngư được trang bị súng máy có cỡ nòng đến 14,5mm?',
#  '137274': 'Lãnh đạo Cục Ngoại vụ gồm những ai?',
#  '149865': 'Thẩm quyền huy động vốn tại doanh nghiệp Nhà nước thuộc về cơ quan nào?',
#  '137074': 'Người lao động bị chậm trả lương thì được quyền đơn phương chấm dứt hợp đồng lao động không?',
#  '98477': 'Ban quản lý cơ sở tín ngưỡng thông báo đến cơ quan nhà nước các khoản thu từ việc tổ chức lễ hội tín ngưỡng trong bao lâu?',
#  '140069': 'Đề nghị các công ty đại chúng tuân thủ quy định khi tổ chức kỳ họp Đại hội đồng cổ đông?',
#  '113407': 'Ngân hàng thương mại ban hành quy định nội bộ về cấp tín dụng, quản lý nợ tối thiểu cần đáp ứng những yêu cầu gì?',
#  '162703': 'Cá nhân muốn trở thành hội viên danh dự của Hiệp hội Xuất khẩu lao động Việt Nam cần đáp ứng được yêu cầu gì?',
#  '11067': 'Chi phí đăng tải thông tin về đấu thầu trên Hệ thống mạng đấu thầu quốc gia là bao nhiêu?',
#  '60175': 'Có cấm việc cho người chơi vay tiền để đặt cược không?',
#  '49811': 'Hồ sơ, thủ tục chi trả phụ cấp chức vụ lãnh đạo đối với sĩ quan quân đội biệt phái được quy định ra sao?',
#  '80135': 'Đảng viên thành lập, tham gia quản lý, điều hành doanh nghiệp trái quy định của pháp luật sẽ bị xử lý như thế nào?',
#  '40180': 'Trình tự thủ tục thu hồi Giấy chứng nhận thành viên lưu ký của ngân hàng thương mại khi bị thu hồi Giấy chứng nhận đăng ký hoạt động lưu ký chứng khoán thực hiện như thế nào?',
#  '39082': 'Đại diện chủ sở hữu nhà nước trực tiếp tại Tập đoàn công nghiệp than khoáng sản Việt Nam là ai?',
#  '15431': 'Chủ tịch UBND cấp huyện có quyền xử phạt hành chính đối với hành vi không thực hiện đăng ký sĩ quan dự bị lần đầu không?',
#  '71802': 'Cơ quan điều tra tiến hành tạm đình chỉ giải quyết tin báo về tội phạm trong những trường hợp nào?',
#  '74627': 'Hồ sơ cán bộ, công chức trong tổ chức công đoàn được quản lý, sử dụng và bảo quản theo chế độ nào?',
#  '156222': 'Mức thu lệ phí trước bạ ô tô theo Nghị định 10/2022/NĐ-CP là bao nhiêu?',
#  '37091': 'Người học ngành công tác xã hội trình độ trung cấp thì phải có khả năng học tập, nâng cao trình độ như thế nào?',
#  '10448': 'Ai được thương thảo hợp đồng khi đấu thầu theo phương thức một giai đoạn một túi hồ sơ?',
#  '84479': 'Nhân viên thử việc bị ốm thì có được hưởng chế độ ốm đau hay không?',
#  '22593': 'Sau khi đánh giá hồ sơ dự thầu và lựa chọn được danh sách xếp hạng nhà thầu thì có cần gửi bên mời thầu để xem xét không?',
#  '153264': 'Người lao động có phải đóng kinh phí công đoàn khi công ty không thành lập công đoàn hay không?',
#  '153903': 'Thành viên Hội đồng Lý luận Trung ương có trách nhiệm tham dự đầy đủ các cuộc họp của tiểu ban hay không?',
#  '27873': 'Trường hợp nào được cấp lại thẻ hướng dẫn viên du lịch?',
#  '95292': 'Cơ quan lãnh đạo cao nhất của Liên đoàn luật sư Việt Nam là cơ quan nào?',
#  '30203': 'Thời gian quyết định đóng tạm thời cảng hàng không, sân bay khi có thiên tai, dịch bệnh, ô nhiễm môi trường, sự cố, tai nạn hàng không là bao lâu?',
#  '138195': 'Đối tượng nào được cung cấp dịch vụ kế toán qua biên giới cho các doanh nghiệp, tổ chức tại Việt Nam?',
#  '158226': 'Việc phối hợp công tác và trao đổi thông tin giữa Tổng cục Thuế và Tổng cục Thống kê gồm những hoạt động nào?',
#  '139632': 'Trang thông tin điện tử nào không cần phải đăng ký cấp phép?',
#  '108815': 'Trình tự, thủ tục thẩm định, phê duyệt kế hoạch sử dụng đất hàng năm cấp huyện như thế nào?',
#  '29844': 'Cơ sở đào tạo tôn giáo có thể giải thể theo quyết định của tổ chức tôn giáo không?',
#  '99585': 'Cổng thông tin điện tử thị trường điện phục vụ công tác trao đổi thông tin thị trường điện giữa các đơn vị nào?',
#  '86939': 'Đánh giá đột xuất mức độ mức độ tuân thủ Thực hành tốt bảo quản thuốc, nguyên liệu làm thuốc đạt yêu cầu thì cơ sở bảo quản có được cấp Giấy chứng nhận đủ điều kiện kinh doanh dược hay không?',
#  '19401': 'Cửa hàng bán hàng hóa của Lào tại Việt Nam thì có những nghĩa vụ nào?',
#  '71770': 'Không lập Báo cáo đánh giá tác động môi trường trong trường hợp có thay đổi về quy mô công suất sản xuất so với quyết định phê duyệt ban đầu có bị phạt hay không?',
#  '150715': 'Khi nào các phiên họp của Hội đồng Giáo sư cơ sở xét công nhận đạt tiêu chuẩn chức danh giáo sư được tiến hành?',
#  '157669': 'Thủ tục đề nghị cấp giấy phép trang bị vũ khí quân dụng, công cụ hỗ trợ được quy định như thế nào?',
#  '5564': 'Nữ công an nhân dân mang thai hộ thì trong thời kỳ mang thai được nghỉ việc để khám thai bao nhiêu lần?',
#  '58127': 'Lệ phí sát hạch, cấp giấy phép lái xe hạng B2 là bao nhiêu?',
#  '127318': 'Nhà nước kiểm soát doanh nghiệp hoạt động trong lĩnh vực độc quyền nhà nước bằng các biện pháp nào?',
#  '4722': 'Người tiếp công dân trong Bộ Quốc phòng cần có những tiêu chuẩn gì?',
#  '74493': 'Không muốn khiếu nại nữa thì người khiếu nại có được rút khiếu nại hay không?',
#  '67964': 'Hợp đồng học nghề phải bao gồm những nội dung gì theo quy định hiện nay?',
#  '138245': 'Cãi lời bố mẹ để kết hôn có bị coi là vi phạm pháp luật không?',
#  '97699': 'Trường hợp chưa ly hôn mà ngoại tình với người khác có bị xử phạt không?',
#  '26609': 'Các quốc gia thực hiện việc giáo dục cho người khuyết tật phải có định hướng như thế nào?',
#  '17955': 'Trong việc thực hiện Đề án Hỗ trợ phụ nữ khởi nghiệp giai đoạn 2017 - 2025 thì Trung ương Hội Liên hiệp Phụ nữ Việt Nam có những trách nhiệm gì?',
#  '1209': 'NLĐ xin nghỉ không hưởng lương mà thời gian nghỉ trùng với lễ, tết thì có được nhận lương những ngày này không?',
#  '77495': 'Giám thị trại giam có quyền ra quyết định kỷ luật phạm nhân không?',
#  '70604': 'Đối tượng nào phải đóng đoàn phí công đoàn?',
#  '111658': 'Giáo viên sẽ phải đền bù chi phí đào tạo nâng trình độ chuẩn khi không được cơ sở đào tạo cấp bằng tốt nghiệp đúng không?',
#  '121844': 'Người nào có thẩm quyền đề nghị cấp thẻ thanh tra cho Thanh tra Bộ Giao thông vận tải?',
#  '62525': 'Thủ tục cần làm khi cổ đông công ty cổ phần chuyển nhượng cổ phần cho cổ đông còn lại hoặc bán cho người khác là gì?',
#  '8566': 'Hộ nghèo có thuộc đối tượng được Nhà nước miễn tiền sử dụng đất hay không?',
#  '94568': 'Mức phụ cấp đặc thù đối với nhân viên quân y khám chữa bệnh cho bị can ở các trại tạm giam được chi trả khi nào?',
#  '16653': 'Chẩn đoán cận lâm sàng sai khớp cắn loại 2 do quá phát xương hàm trên như thế nào?',
#  '84277': 'Việc lập và lưu giữ Giấy phép bán lẻ sản phẩm thuốc lá được thực hiện như thế nào?',
#  '97629': 'Công ty có quyền đơn phương chấm dứt hợp đồng lao động trong những trường hợp nào?',
#  '48730': 'Cơ quan nào có trách nhiệm bán nhà ở cũ thuộc sở hữu nhà nước?',
#  '133689': 'Hồ sơ đề nghị khảo nghiệm giống thủy sản được gửi cho cơ quan nào?',
#  '32770': 'Phụ cấp trách nhiệm đối với lái xe phục vụ Viện trưởng Viện Kiểm sát nhân dân tối cao được chi trả khi nào?',
#  '31699': 'Trường cao đẳng sư phạm do Nhà nước thành lập có trách nhiệm công khai những hoạt động nào?',
#  '142228': 'Sau phẫu thuật tháo dịch điều trị bong hắc mạc, việc xử trí các tai biến có thể xảy ra như thế nào?',
#  '152529': 'Nhà nước có phải bồi thường khi không giảm thời hạn chấp hành hình phạt tù cho người được Tòa án giảm thời hạn chấp hành hình phạt tù không?',
#  '28713': 'Thủ tục chấm dứt quyền hội viên của Hiệp hội Titan Việt Nam được quy định thế nào?',
#  '140667': 'Khi phối hợp điều tra tai nạn lao động thì Đoàn Điều tra tai nạn lao động cấp tỉnh cần thực hiện những gì nếu tai nạn có dấu hiệu phạm tội?',
#  '162560': 'Trường hợp nào người tham gia nghĩa vụ quân sự được xuất ngũ sớm hơn 24 tháng?',
#  '66103': 'Cơ quan nào có quyền thẩm định hồ sơ đề nghị cấp Giấy chứng nhận đủ điều kiện kinh doanh đặt cược bóng đá quốc tế?',
#  '173312': 'Đậu đũa quả tươi hạng II trong mỗi bao gói có cần phải cùng kích cỡ và độ già không?',
#  '69226': 'Thời gian tính hưởng chế độ phụ cấp thâm niên đối với quân nhân chuyên nghiệp được quy định như thế nào?',
#  '67332': 'Điều tra viên trung cấp có trách nhiệm như thế nào?',
#  '154220': 'Viên chức được ký kết hợp đồng làm việc theo loại hợp đồng lao động nào?',
#  '81555': 'Chất hướng thần có phải là ma tuý hay không? Chất hướng thần và thuốc hướng thần có giống nhau hay không?',
#  '12278': 'Thủ tục kết nạp đoàn viên được quy định như thế nào?',
#  '133533': 'Hồ sơ kiểm định định kỳ xe khai thác và xử lý nước thuộc Bộ Quốc phòng sẽ gồm những tài liệu nào?',
#  '153951': 'Người lao động đóng và quản lý tiền đoàn phí thực hiện theo phương thức nào?',
#  '112865': 'Chuyển đổi báo cáo tài chính lập bằng đơn vị tiền tệ thực hiện như thế nào?',
#  '94011': 'Để có thể tuyển dụng nhân sự thì các đơn vị sự nghiệp công lập cần phải làm những gì?',
#  '149938': 'Ai có trách nhiệm công khai ngân sách đối với đơn vị dự toán ngân sách?',
#  '130250': 'Thời gian thực tế công tác tại vùng có điều kiện kinh tế - xã hội đặc biệt khó khăn được xác định như thế nào?',
#  '75716': 'Phó Chủ tịch Hội đồng quản lý Quỹ Hoa Mặt có những nhiệm vụ gì?',
#  '50391': 'Chi phí trước khi thành lập doanh nghiệp có được khấu trừ thuế không?',
#  '48546': 'Đơn vị, bộ phận được phân công quản lý hồ sơ vụ án hình sự tạm đình chỉ kiểm tra các đơn vị, cá nhân được phân công thực hành quyền kiểm sát việc tạm đình chỉ vụ án định kỳ bao lâu?',
#  '119476': 'Thuốc Alfuzosin (Xatral) có nằm trong danh mục được bảo hiểm chi trả không?',
#  '129846': 'Cơ quan thường trực của Ban Chỉ huy Phòng thủ dân sự cấp tỉnh là cơ quan nào?',
#  '94767': 'Tòa án quyết định giải quyết vụ án dân sự theo thủ tục rút gọn khi có các điều kiện gì?',
#  '37907': 'Khi làm nhiệm vụ bảo vệ tiếp cận đối với đối tượng cảnh vệ là lãnh đạo cấp cao thì chiến sĩ cảnh vệ có được kiểm tra, kiểm soát người không?',
#  '164657': 'Rà soát quy hoạch đô thị định kỳ sẽ là bao lâu một lần?',
#  '144601': 'Hội đồng tuyển dụng quân nhân chuyên nghiệp, công nhân và viên chức quốc phòng gồm những ai?',
#  '124586': 'Xử lý tiền ký quỹ của người lao động trong một số trường hợp cụ thể như thế nào?',
#  '13263': 'Phẫu thuật viên có thể thực hiện phẫu thuật điều trị hở mi không? Người bệnh được chỉ định phẫu thuật điều trị hở mi khi nào?',
#  '163158': 'Kiến thức pháp luật về cứu nạn cứu hộ gồm các nội dung nào?',
#  '131971': 'Lãnh đạo Đội Điều tra hình sự trực thuộc Cục Điều tra chống buôn lậu bao gồm những ai?',
#  '126866': 'Công ty sa thải người lao động trái luật bị phạt bao nhiêu?',
#  '35527': 'Người lao động được lựa chọn tham gia chính sách việc làm công theo thứ tự ưu tiên như thế nào?',
#  '54075': 'Người phát ngôn và cung cấp thông tin cho báo chí của Bộ Xây dựng là ai?',
#  '77717': 'Nghỉ 3 tháng trước khi sinh con có được hưởng chế độ thai sản không?',
#  '52351': 'Hộ gia đình có người hoạt động kháng chiến bị nhiễm chất độc hóa học có được hỗ trợ về nhà ở theo quy định hiện nay?',
#  '78617': 'Việc tính hưởng trợ cấp tinh giản biên chế được quy định thế nào?',
#  '74490': 'Công dân đạt thành tính học sinh giỏi cấp tỉnh được tuyển chọn vào Công an nhân dân theo phương thức nào?',
#  '79589': 'Giám đốc ngân hàng có thể dùng tài sản của mình để bảo đảm cho bên thứ ba vay vốn không?',
#  '32952': 'Người làm công tác cơ yếu không phải là quân nhân, Công an nhân dân khi nghỉ hưu sẽ được hưởng quyền lợi gì?',
#  '74961': 'Trường hợp không thể xác định giá trị tang vật, phương tiện vi phạm hành chính thì phải giải quyết như thế nào?',
#  '36797': 'Điều kiện để được tham gia tập sự trợ giúp pháp lý?',
#  '179223': 'Hiệp hội Chống hàng giả và bảo vệ quyền sở hữu trí tuệ của các doanh nghiệp có vốn đầu tư nước ngoài tại Việt Nam chịu sự quản lý nhà nước của cơ quan nào?',
#  '69275': 'Trách nhiệm của các cơ quan ban ngành trong việc xử lý hành vi đốt và thả đèn trời như thế nào?',
#  '91035': 'Chức danh nghề nghiệp quản lý dự án đường thủy hạng 4 thực hiện những nhiệm vụ gì?',
#  '152504': 'Công nhận danh hiệu giáo viên dạy giỏi trong cơ sở giáo dục mầm non được quy định như thế nào?',
#  '80321': 'Cơ quan lãnh đạo cao nhất của Hội Hữu nghị Việt và Bỉ là cơ quan nào?',
#  '138337': 'Viên chức Cảng vụ hàng hải khi bị kỷ luật bằng hình thức buộc thôi việc thì viên chức phải nộp lại những gì?',
#  '120881': 'Các dữ liệu được ghi và lưu trữ trên camera giám sát hành trình quy định tối thiểu trong bao nhiêu ngày?',
#  '147588': 'Bệnh nhân khi phẫu thuật điều trị bọng mỡ mi mắt qua đường rạch da được theo dõi như thế nào?',
#  '62187': 'Nhiệm vụ, quyền hạn của Chấp hành viên cao cấp được quy định như thế nào?',
#  '164857': 'Thời hiệu xử phạt vi phạm hành chính đối với tổ chức khảo nghiệm thuốc thú y không lưu giữ tài liệu liên quan đến việc khảo nghiệm là bao lâu?',
#  '47696': 'Đại học vùng có được quyết định mở ngành đào tạo trình độ đại học cho các trường đại học thành viên không?',
#  '109419': 'Bằng khen của Bộ trưởng Bộ Quốc phòng để tặng cho những cá nhân có thành tích gì?',
#  '138859': 'Trách nhiệm khai hải quan của công ty chuyển phát nhanh khi thực hiện chuyển phát được quy định như thế nào?',
#  '38072': 'Doanh nghiệp có được hỗ trợ lãi suất vay khi vay vốn trực tiếp từ Quỹ Đổi mới công nghệ quốc gia hay không?',
#  '119771': 'Sổ theo dõi tài sản đấu giá hiện nay sử dụng theo mẫu nào?',
#  '135276': 'Hợp đồng làm việc của viên chức có nội dung và hình thức như thế nào?',
#  '163683': 'Chưa thực hiện được việc định giá tài sản thì Chấp hành viên có thể giao phần đất đã kê biên cho người phải thi hành án tạm quản lý không?',
#  '31804': 'Nội dung sát hạch về kỹ năng dừng tàu với thí sinh sát hạch thực hành lái tàu cấp giấy phép lái tàu trên đường sắt quốc gia gồm những gì?',
#  '4149': 'Cục Tần số vô tuyến điện tham mưu giúp Bộ trưởng Bộ Thông tin và Truyền thông thực hiện nhiệm vụ quản lý nhà nước nào?',
#  '106461': 'Xác định protein có thể ngâm chiết trong găng tay y tế sử dụng một lần bằng phương pháp nào?',
#  '39824': 'Hội đồng nhân dân thị trấn có quyền bãi bỏ văn bản trái pháp luật của Ủy ban nhân dân, Chủ tịch Ủy ban nhân dân thị trấn hay không?',
#  '80618': 'Thi nâng hạng giấy phép lái xe hạng D lên hạng E nộp hồ sơ ở đâu?',
#  '68848': 'Trung tâm Giám định bảo hiểm y tế và Thanh toán đa tuyến có bao nhiêu Phó Giám đốc?',
#  '58141': 'Người được công nhận là cựu chiến binh được hưởng những quyền lợi gì khi mất?',
#  '142859': 'Doanh nghiệp nước ngoài được xét trở thành hội viên của Hiệp hội Chống hàng giả và bảo vệ quyền sở hữu trí tuệ cần đáp ứng được yêu cầu gì?',
#  '56616': 'Cần thay đổi quy mô giường bệnh thì bệnh viện quân y cần chuẩn bị những giấy tờ gì cho hồ sơ đề nghị cấp điều chỉnh giấy phép hoạt động?',
#  '23412': 'Trách nhiệm bảo hành nhà chung cư thuộc về ai?',
#  '62266': 'Quỹ tiền lương làm căn cứ đóng kinh phí công đoàn được xác định như thế nào?',
#  '58792': 'Thời hạn để hộ gia đình nộp hồ sơ khai thuế giá trị gia tăng năm 2023 theo phương pháp khoán là khi nào?',
#  '98568': 'Người bị kết án phạt tù có nơi làm việc ổn định có được xem là một trong các điều kiện được xem xét hưởng án treo không?',
#  '66725': 'Trường hợp nào được biệt phái viên chức?',
#  '111880': 'Tổ chức đề nghị bay chụp ảnh hàng không thì bao nhiêu ngày thì nhận được sự trả lời của Bộ Quốc phòng?',
#  '120882': 'Cấu trúc khung truyền dữ liệu từ camera giám sát hành trình đến máy tính cần tuân thủ theo những yêu cầu gì?',
#  '27437': 'Khi quy hoạch xây dựng vùng liên huyện phải thực hiện những nhiệm vụ gì?',
#  '104311': 'Bệnh viêm gan vi rút B nghề nghiệp có phải là bệnh nghề nghiệp được hưởng bảo hiểm xã hội không?',
#  '45820': 'Hội đồng xét kỷ luật đối với học sinh trường giáo dưỡng có cơ cấu tổ chức như thế nào?',
#  '2155': 'Thân nhân của Công an nhân dân được ngân sách nhà nước đóng Bảo hiểm y tế gồm có những ai?',
#  '61294': 'Ai có thẩm quyền quyết định bổ nhiệm Phó Chủ tịch kiêm Tổng thư ký Hội đồng Giáo sư nhà nước?',
#  '119409': 'Việc xét miễn, giảm thi hành án dân sự đối với khoản thu, nộp ngân sách nhà nước được thực hiện theo nguyên tắc nào?',
#  '69466': 'Lãi suất vay ngân hàng để mua nhà chung cư là bao nhiêu?',
#  '10133': 'Phương án thế chấp tài sản sẽ do ai tại Tập đoàn công nghiệp than khoáng sản Việt Nam quyết định?',
#  '47868': 'Nhân viên y tế chuyên khoa lao nếu muốn xin giảm thời gian làm việc có được không?',
#  '9014': 'Doanh nghiệp bảo hiểm có trách nhiệm gì trong công tác phòng chống gian lận bảo hiểm trong bảo hiểm nông nghiệp?',
#  '128778': 'Di chúc không hợp pháp thì sẽ chia thừa thế như thế nào?',
#  '13797': 'Tòa án quân sự trung ương có các chức danh tư pháp nào?',
#  '26321': 'Người phụ thuộc là mẹ kế thì sẽ có mức giảm trừ gia cảnh là bao nhiêu?',
#  '63156': 'Nhà đầu tư mở tài khoản vốn đầu tư dự án dầu khí ra nước ngoài tại cơ quan nào?',
#  '94816': 'Người tập sự hành nghề Thừa phát lại phải đảm bảo thời gian tập sự ít nhất bao nhiêu giờ mỗi ngày?',
#  '23082': 'Kiểm toán độc lập báo cáo tài chính của tổ chức tài chính vi mô gồm những nội dung gì?',
#  '80764': 'Còng số 8 có phải là công cụ hỗ trợ không?',
#  '55497': 'Trái phiếu doanh nghiệp được thực hiện giao dịch mua, bán khi đáp ứng đủ các yêu cầu nào?',
#  '130496': 'Quy định về hóa đơn đối với hàng hoá, dịch vụ khuyến mại như thế nào?',
#  '33738': 'Không thực hiện chế độ báo cáo hoạt động đầu tư ra nước ngoài thì doanh nghiệp bị xử phạt như thế nào?',
#  '62652': 'Bộ Nội vụ thực hiện đánh giá chất lượng chương trình, tài liệu bồi dưỡng cán bộ, công chức, viên chức theo những phương thức nào?',
#  '87605': 'Người lao động là người nước ngoài làm việc tại Việt Nam thì có được nghỉ lễ Quốc khánh hay không?',
#  '52240': 'Nhiệm vụ của Đoàn Chủ tịch Hội Cựu thanh niên xung phong Việt Nam là gì?',
#  '101517': 'Các hành vi tham nhũng trong khu vực ngoài nhà nước do người có chức vụ, quyền hạn trong tổ chức khu vực ngoài nhà nước thực hiện bao gồm những hành vi nào?',
#  '172206': 'Chứng thực hợp đồng chuyển nhượng quyền sử dụng đất cần xuất trình những giấy tờ gì?',
#  '73871': 'Hồ sơ đề nghị cấp lại Giấy chứng nhận đăng ký phương tiện giao thông đường sắt khi thay đổi thông số kỹ thuật cần những gì?',
#  '26514': 'Tổ chức muốn kiểm kê di sản văn hóa phi vật thể thì trong hồ sơ gồm có những gì?',
#  '93290': 'Quỹ chăm sóc người cao tuổi hoạt động dựa trên những nguyên tắc nào?',
#  '173217': 'Trung tâm Lưu ký Chứng khoán Việt Nam thực hiện những chức năng gì?',
#  '31548': 'Khi kê đơn thuốc y học cổ truyền thì bác sỹ thực hiện ghi đơn thuốc như thế nào?',
#  '13508': 'Cần làm gì nếu chưa nhận được tiền bồi thường khi nhà nước thu hồi đất?',
#  '17017': 'Điều kiện hưởng chế độ tai nạn lao động ra sao?',
#  '72792': 'Thời gian cấp giấy phép khai thác cơ sở cung cấp dịch vụ bảo đảm hoạt động bay là bao lâu?',
#  '33133': 'Ai có quyền cấp giấy phép hoạt động bến thủy nội địa thuộc phạm vi quản lý của Bộ Quốc phòng?',
#  '142321': 'Cá nhân được giao khu vực biển để nuôi trồng thủy sản có những quyền hạn nào?',
#  '131296': 'Bãi bỏ khung giá đất có tác động đến các quy định về bảng giá đất tại địa phương như thế nào?',
#  '48072': 'Tổ chức tín dụng được phép hoạt động trong phạm vi nào?',
#  '50354': 'Kinh phí quản lý hành chính về chi khám sức khỏe định kỳ hàng năm trong cơ quan Nhà nước được quy định ra sao?',
#  '123289': 'Điều kiện để thăng cấp bậc hàm trước thời hạn từ Đại tá lên Thiếu tướng Công an nhân dân như thế nào?',
#  '34426': 'Quy trình bảo trì công trình đường bộ bao gồm những nội dung nào?',
#  '98429': 'Chủ nhà không thực hiện giao dịch mà cũng không trả lại tiền đặt cọc thì người đặt cọc có quyền nộp đơn khởi kiện ra Tòa án không?',
#  '135517': 'Hội đồng thẩm định kịch bản phim sử dụng ngân sách nhà nước làm việc dựa theo nguyên tắc nào?',
#  '160723': 'Nhà giáo dạy trình độ trung cấp chuẩn bị và thực hiện hoạt động giảng dạy như thế nào để đáp ứng tiêu chí về năng lực sư phạm?',
#  '37951': 'Tổ chức cá nhân như thế nào là bán, chuyển nhượng, cho thuê, cho thuê mua bất động sản quy mô nhỏ, không thường xuyên?',
#  '97262': 'Hồ sơ đề nghị công nhận hòa giải viên thuộc thẩm quyền giải quyết của cấp xã cần những gì?',
#  '101812': 'Luật sư nước ngoài có được hành nghề Quản tài viên ở Việt Nam hay không?',
#  '58184': 'Giao nhận đối tượng trưng cầu giám định tư pháp trong lĩnh vực nông nghiệp và phát triển nông thôn được quy định ra sao?',
#  '122031': 'Mũ bảo hiểm có bao nhiêu loại và kết cấu như thế nào?',
#  '33383': 'Giấy chứng nhận đăng ký hoạt động thử nghiệm chất lượng sản phẩm, hàng hóa được cấp lại trong trường hợp nào?',
#  '179199': 'Tiếp tục gia hạn thuế giá trị gia tăng, thuế thu nhập cá nhân của hộ kinh doanh, cá nhân kinh doanh năm 2022?',
#  '78952': 'Ai có thẩm quyền công bố số liệu thống kê đánh giá thiệt hại do thiên tai gây ra?',
#  '120523': 'Công tác phòng không nhân dân là gì?',
#  '50169': 'Chánh Thanh tra Sở Lao động - Thương binh và Xã hội có quyền xử phạt người gian lận hồ sơ tuyển sinh để được hưởng chính sách đối với người học trong giáo dục nghề nghiệp không?',
#  '105380': 'Đại lý dịch vụ viễn thông cung cấp dịch vụ viễn thông trong thời gian nào?',
#  '125141': 'Có được tiến hành bắt bị can để tạm giam vào ban đêm không?',
#  '132915': 'Tiền đặt trước khối băng tần là bao nhiêu?',
# ...
#  '155290': 'Những trường hợp nào sẽ xóa đăng ký tạm trú?',
#  '141547': 'Giá trị sản xuất của trang trại trồng trọt được quy định như thế nào?',
#  '164123': 'Có các hình thức cách ly nào đối với người mắc bệnh truyền nhiễm nhóm B phải cách ly y tế?',
#  '122615': 'Thời hạn nộp chi phí đăng tải thông tin về đấu thầu trên Báo Đấu thầu được quy định thế nào?',
#  '113066': 'Hàm ngoại giao có phải là chức danh Nhà nước không?',
#  '87212': 'Việc kiểm tra cư trú đối với công dân được thực hiện như thế nào?',
#  '61569': 'Ban Quản lý chương trình, dự án hỗ trợ kỹ thuật của Kiểm toán Nhà nước có các chức năng như thế nào?',
#  '151810': 'Cơ quan quản lý cần cung cấp những thông tin nào khi thực hiện việc thu phí, lệ phí thông qua Cổng thông tin một cửa quốc gia?',
#  '24052': 'Ban Tổ chức Lễ tang đối với cán bộ Quân đội giữ chức vụ Phó Chính ủy Bộ đội Biên phòng có bao nhiêu thành viên?',
#  '65462': 'Chứng cứ để chứng minh khi nhận cha mẹ con cần có những gì?',
#  '101555': 'Trường mầm non tư thục có phải nộp lệ phí môn bài không?',
#  '26250': 'Chủ tịch hội đồng thành viên công ty trách nhiệm hữu hạn hai thành viên có được ký kết hợp đồng thay Tổng giám đốc hay không?',
#  '111219': 'Thời hạn gửi bản án, quyết định cho các bên liên quan là bao lâu?',
#  '3496': 'Có thể đăng ký mã QR làm nhãn đánh dấu cho sản phẩm lâm sản hay không?',
#  '30102': 'Thủ tục đăng ký thay đổi tên cho con thực hiện như thế nào?',
#  '158673': 'Hội viên của Hội Đá quý Việt Nam có những nhiệm vụ nào?',
#  '138992': 'Trách nhiệm của Quốc hội và Ủy ban thường vụ Quốc hội khi thực hiện chức năng giám sát được quy định thực hiện như thế nào?',
#  '43109': 'Lịch thanh toán nguyện vọng đại học 2023 ra sao?',
#  '135655': 'Trường hợp lập di chúc không hợp pháp thì di sản thừa kế được chia như thế nào?',
#  '159058': 'Để được bổ nhiệm đăng kiểm viên tàu biển thực hiện công tác đánh giá quản lý an ninh hàng hải thì cần có ít nhất bao nhiêu năm kinh nghiệm?',
#  '129229': 'Chuyển nhượng quyền sử dụng đất cho em họ có được miễn thuế thu nhập cá nhân theo quy định không?',
#  '1877': 'Hoạt động tư vấn chuyên ngành điện lực chỉ được phép áp dụng đối với các hạng mục nào?',
#  '82356': 'Thủ tục cấp Giấy phép nhập khẩu sản phẩm thuốc lá để kinh doanh hàng miễn thuế được quy định thế nào?',
#  '123497': 'Người quảng cáo có trách nhiệm gì khi gửi tin nhắn đăng ký quảng cáo đầu tiên và duy nhất?',
#  '39866': 'Điều kiện để được chuyển ngành, chuyển nơi học, chuyển cơ sở đào tạo, chuyển hình thức học đối với sinh viên?',
#  '37669': 'Giao dịch nào của quỹ đầu tư khởi nghiệp sáng tạo phải được Đại hội nhà đầu tư thông qua?',
#  '97573': 'Giám đốc Trung tâm phải tổ chức, điều hành Trung tâm giới thiệu sản phẩm Việt Nam tại nước ngoài như thế nào?',
#  '94657': 'Điều kiện để trở thành thuyền phó phương tiện thủy nội địa?',
#  '158312': 'Công chức là gì?',
#  '122524': 'Hội Hữu nghị Việt Nam Ấn Độ có những nhiệm vụ như thế nào?',
#  '138547': 'Lực lượng kiểm soát an ninh hàng không có những nhiệm vụ, quyền hạn gì?',
#  '133706': 'Tiêu chuẩn về đạo đức nghề nghiệp của giáo viên giáo dục nghề nghiệp lý thuyết là gì?',
#  '96198': 'Văn phòng Tổng cục Lâm nghiệp thực hiện nhiệm vụ gì trong công tác tổng hợp, thông tin?',
#  '163359': 'Thời hạn đình chỉ một phần hoặc toàn bộ hoạt động đăng ký, lưu ký chứng khoán của Tổng công ty lưu ký và bù trừ chứng khoán Việt Nam là bao lâu và có được gia hạn không?',
#  '154937': 'Trình tự thủ tục đăng ký biến động đất đai trong trường hợp thông tin số giấy tờ tùy thân thay đổi như thế nào?',
#  '75338': 'Thời gian thẩm định hồ sơ đăng ký dự thi nâng ngạch Thẩm phán trung cấp là bao lâu?',
#  '87904': 'Áp dung phương pháp realtime PCR để chấn đoán bệnh Marek ở gà thì cần chuẩn bị những gì?',
#  '64462': 'Vụ Kế hoạch Tài chính trực thuộc Bộ Tài nguyên và Môi trường có bao nhiêu phòng chuyên môn?',
#  '160338': 'Quyết định áp dụng biện pháp tự vệ tạm thời được thông báo công khai với những nội dung gì?',
#  '75577': 'Tổ chức tài chính phải làm gì đối với giao dịch có giá trị lớn bất thường?',
#  '73607': 'Điều trị bảo tồn gẫy thân xương cánh tay được hiểu ra sao?',
#  '95517': 'Cách ghi hạn sử dụng trên nhãn hàng hóa của thực phẩm được quy định thế nào?',
#  '117876': 'Nguyên tắc áp dụng mức lương tối thiểu theo giờ được quy định như thế nào?',
#  '80130': 'Việc yêu cầu các tổ chức, cá nhân không tuân thủ các quy định của pháp luật về kinh doanh thuốc lá thực hiện biện pháp khắc phục là trách nhiệm của cơ quan nào?',
#  '114477': 'Hồ sơ đăng ký xét tuyển chương trình đào tạo sơ cấp lý luận chính trị tại Trung tâm gồm những gì?',
#  '140694': 'Xúi giục hoặc giúp bệnh nhân sớm kết thúc sự sống bị phạt bao nhiêu năm?',
#  '155124': 'Thứ trưởng, Phó chủ nhiệm Ủy ban Dân tộc có trách nhiệm và quyền hạn gì trong phạm vi công việc được phân công?',
#  '89242': 'Hợp đồng cho vay tiền bằng ngoại tệ có thể được công chứng hay không?',
#  '139665': 'Chủ tịch Hội đồng chấm thi kỳ thi chọn học sinh giỏi quốc gia là ai? Hội đồng chấm thi có cơ cấu và thành phần như thế nào?',
#  '108450': 'Thiếu úy quân đội là chức vụ gì?',
#  '30532': 'Khi nhận được nhiệm vụ do Chính phủ, Thủ tướng Chính phủ giao, lãnh đạo Bảo hiểm xã hội Việt Nam có trách nhiệm gì?',
#  '5639': 'Khoản nhận nợ giữa bên đi vay và bên bảo đảm trong khoản vay nước ngoài là gì?',
#  '74598': 'Tập huấn, sát hạch của kiểm tra viên điện lực được thực hiện như thế nào?',
#  '120078': 'Doanh nghiệp quảng cáo bia trên kênh Youtube dành cho trẻ em sẽ bị xử phạt như thế nào?',
#  '64916': 'Tiếp tục thực hiện Công văn 735/UBND-KGVX ngày 15/3/2022 của UBND Thành phố và mở cửa lại các hoạt động du lịch',
#  '57103': 'Người sử dụng thư viện đại học có những quyền gì?',
#  '11280': 'Mức phụ cấp đặc thù áp dụng đối với Phó Viện trưởng Viện kiểm sát quân sự trung ương là bao nhiêu?',
#  '90399': 'Để được nhận con nuôi là con riêng của chồng thì mẹ kế cần đáp ứng điều kiện nào?',
#  '150657': 'Thương nhân kinh doanh Siêu thị kinh doanh tổng hợp có thể tự tiến hành phân hạng Siêu thị của mình không?',
#  '106162': 'Trách nhiệm của Bộ đội Biên phòng trong quản lý nhà nước về hoạt động đối ngoại biên phòng được quy định thế nào?',
#  '151616': 'Chủ tịch Ủy ban nhân dân cấp huyện có quyền xử phạt người sử dụng thuốc bảo vệ thực vật sai quy định và gây ô nhiễm môi trường không?',
#  '48018': 'Đối tượng vay vốn bao gồm những đối tượng nào? Phương thức cho vay bao gồm những phương thức nào?',
#  '117508': 'Hồ sơ nhập học lớp 10 chuyên tại TP Hồ Chí Minh gồm những gì?',
#  '55357': 'Có được liên thông thư viện giữa các trường trung học phổ thông không cùng một địa bàn tỉnh hay không?',
#  '102876': 'Cơ quan điều tra Viện kiểm sát nhân dân tối cao có được sử dụng động vật nghiệp vụ không?',
#  '142993': 'Điều khiển xe ô tô tham gia giao thông nhưng không mang theo Giấy chứng nhận kiểm định xe thì bị xử phạt thế nào?',
#  '136810': 'Việc trả lương cho người lao động phải tuân thủ những nguyên tắc nào?',
#  '33642': 'Hội đồng thành viên của tổ chức tín dụng là gì?',
#  '135800': 'Tỷ lệ vốn nhà nước hỗ trợ xây dựng công trình, hệ thống cơ sở hạ tầng trong dự án đầu tư theo phương thức đối tác công tư được xác định trên cơ sở nào?',
#  '4674': 'Người bị buộc tội thì có bị xem là tội phạm hay không?',
#  '52050': 'Chung cư có hạn mức là 50 năm có đúng hay không?',
#  '18633': 'Vị trí và chức năng của Cục Thủy lợi được quy định như thế nào?',
#  '106045': 'Việc điều chỉnh vốn điều lệ trong quá trình hoạt động của Tổng công ty Viễn thông MobiFone do ai quyết định?',
#  '118991': 'Lãnh đạo Vườn quốc gia Cát Tiên do ai bổ nhiệm?',
#  '33760': 'Việc miễn thủ tục rời cảng biển đối với các trường hợp đặc biệt được quy định thế nào?',
#  '149175': 'Việc khám xét nhà người khác được quy định như thế nào?',
#  '3732': 'Hồ sơ đề nghị cấp lại Giấy phép và năng định cho nhân viên bảo dưỡng tàu bay trong trường hợp hết hạn gồm những nội dung gì?',
#  '58890': 'Nhặt được của rơi nếu không biết địa chỉ của người đánh rơi thì xử lý như thế nào?',
#  '63938': 'Trưởng Đoàn thanh tra chuyên ngành hải quan có thể bị thay đổi trong trường hợp nào?',
#  '30974': 'Khi nào tổ chức đăng ký tham gia trợ giúp pháp lý chấm dứt thực hiện trợ giúp pháp lý?',
#  '46049': 'Ủy viên Chuyên môn và Ủy viên Thường trực Hội đồng Giám định y khoa có nhiệm vụ gì?',
#  '75837': 'Hệ thống cung ứng dịch vụ tiêm chủng được quy định thế nào?',
#  '39185': 'Điều kiện sản xuất rượu công nghiệp và rượu thủ công nhằm mục đích kinh doanh được quy định thế nào?',
#  '127884': 'Ai có quyền cấp thẻ Thanh tra Kiểm toán nhà nước cho thanh tra viên của Kiểm toán nhà nước sử dụng khi thực hiện nhiệm vụ thanh tra?',
#  '165259': 'Công ty cổ phần có vốn đầu tư nước ngoài có được mua nhà ở gắn liền với đất ở Việt Nam không?',
#  '24576': 'Có bị xem là vi phạm thay đổi kết cấu xe khi thay đổi loại bánh căm hay không?',
#  '126166': 'Hội đồng thẩm định hồ sơ đề nghị cấp Giấy phép tiếp cận nguồn gen để nghiên cứu vì mục đích thương mại có bao nhiêu thành viên?',
#  '86389': 'Phương tiện giao thông dùng để vận chuyển hàng siêu trường, siêu trọng là gì?',
#  '30343': 'Quỹ đầu tư khởi nghiệp sáng tạo có bắt buộc phải có Ban đại diện quỹ hay không?',
#  '74482': 'Người thi hành công vụ gây thiệt hại có những quyền nào theo luật bồi thường nhà nước?',
#  '158046': 'Kiểm sát viên Viện kiểm sát nhân dân tối cao có bắt buộc phải có bằng cử nhân luật hay không?',
#  '86741': 'Thủ tục cấp giấy chứng nhận đủ điều kiện kinh doanh hóa chất sản xuất kinh doanh có điều kiện khi cơ sở kinh doanh và trụ sở chính cùng ở một địa phương được thực hiện thế nào?',
#  '7750': 'Chủ tịch Ủy ban nhân dân cấp xã có quyền xử phạt người sử dụng phụ gia thực phẩm không rõ nguồn gốc, xuất xứ để chế biến thực phẩm không?',
#  '62585': 'Giải quyết di sản thừa kế của vợ chồng trong trường hợp một bên đã chết như thế nào?',
#  '10918': 'Doanh nghiệp hoạt động xử lý chất thải nguy hại phải đảm bảo về mặt công nghệ như thế nào?',
#  '11093': 'Trường hợp cơ sở sản xuất thức ăn hỗn dành cho cá da trơn không đủ điều kiện sản xuất, thì mức xử phạt là bao nhiêu và thời gian thi hành quyết định xử phạt là bao lâu?',
#  '63874': 'Thời điểm lấy số liệu xây dựng báo cáo sơ kết công tác 6 tháng đầu năm trong ngành Kiểm sát nhân dân từ khi nào?',
#  '102986': 'Hệ thống điện phân phối gặp sự cố làm mất điện trên lưới điện phân phối thì phải giải quyết thế nào?',
#  '25879': 'Hội Răng Hàm Mặt Việt Nam hoạt động dưới sự quản lý của cơ quan nào?',
#  '6266': 'Việc xử lý hợp đồng chuyển quyền sử dụng đối tượng sở hữu công nghiệp được thực hiện theo trình tự, thủ tục nào?',
#  '11100': 'Giấy phép kinh doanh vật liệu nổ công nghiệp bị thu hồi trong trường hợp nào?',
#  '85936': 'Quy định về quyền chất vấn của đại biểu Hội đồng nhân dân như thế nào?',
#  '108958': 'Thực trạng công tác tìm kiếm, quy tập hài cốt hiện nay?',
#  '143414': 'Hiện nay nhà hát được phân chia thành bao nhiêu loại hình?',
#  '55813': 'Tổ chức phát hành thẻ ghi nợ nội địa có trách nhiệm như thế nào đối với phí dịch vụ thẻ ghi nợ nội địa?',
#  '117011': 'Hội Kiến trúc sư Việt Nam có được thành lập các tổ chức có tư cách pháp nhân không?',
#  '78896': 'Quy định về thời gian làm việc của giáo viên trung học phổ thông như thế nào?',
#  '156116': 'Đối tượng của hợp đồng bảo hiểm nhân thọ là gì?',
#  '28099': 'Trái phiếu có bảo đảm là loại trái phiếu gì?',
#  '162160': 'Thư viện cơ sở giáo dục mầm non có những chức năng, nhiệm vụ gì?',
#  '37969': 'Kinh phí thực hiện các nhiệm vụ theo Kế hoạch triển khai thi hành Luật Biên phòng Việt Nam 2020 được sử dụng như thế nào?',
#  '66293': 'Phẫu thuật thắt các mạch máu lớn ngoại vi được chỉ định cho người bệnh khi nào và khi nào không được chỉ định thực hiện?',
#  '13646': 'Khi nào xem xét miễn chấp hành hình phạt đối với tội phạm tham nhũng?',
#  '94783': 'Trường hợp nào thành viên Hội đồng thành viên của Tổng công ty Đầu tư và Kinh doanh vốn nhà nước bị cách chức?',
#  '174573': 'Có những hình thức giải quyết tranh chấp thương mại nào?',
#  '82136': 'Phối hợp tìm kiếm, cứu nạn trong vùng nước cảng biển phải đảm bảo các nguyên tắc nào?',
#  '143418': 'Quyết định công nhận kết quả hòa giải thành tại tòa án có bị kháng cáo theo thủ tục phúc thẩm không?',
#  '154645': 'Hội đồng Trường Cao đẳng nghề Giao thông vận tải Trung ương I thực hiện những nhiệm vụ gì?',
#  '28953': 'Chính mình hoặc có người thân theo đạo thiên chúa thì có được phép đăng ký thi vào trường đào tạo công an nhân dân hay không?',
#  '8121': 'Sau khi tiếp nhận hồ sơ thu hồi vũ khí, vật liệu nổ quân dụng, công cụ hỗ trợ trong trường hợp không còn nhu cầu sử dụng thì cơ quan có thẩm quyền phải thực hiện những thủ tục nào?',
#  '65139': 'Kéo dài thời gian phê duyệt phương án trục vớt tài sản chìm đắm?',
#  '15183': 'Giấy chứng nhận kiểm định hoặc Tem kiểm định bị mất, hư hỏng thì chủ xe có phải đem xe đi kiểm định lại không?',
#  '22707': 'Hồ sơ thu hồi Giấy phép văn phòng đại diện đối với tổ chức tín dụng nước ngoài đề nghị chấm dứt hoạt động gồm những thành phần nào?',
#  '11295': 'Trình tự thực hiện công bố hợp quy đối với tôm sú giống như thế nào?',
#  '44846': 'Có những loại quy mô chăn nuôi nào?',
#  '30413': 'Ai có thẩm quyền cấp Thẻ Hòa giải viên theo quy định hiện nay?',
#  '100669': 'Trình tự, thủ tục xử lý kỷ luật đối với các hành vi trong quân đội được pháp luật quy định như thế nào?',
#  '114327': 'Thời hiệu xử phạt vi phạm hành chính đối với người giả mạo thông tin của cá nhân khác để tham gia hoạt động thương mại điện tử là bao lâu?',
#  '149782': 'Vi phạm quy định về tổ chức giảng dạy bao gồm những hành vi nào theo quy định mới?',
#  '98661': 'Xuất nhập khẩu mẫu thực phẩm chức năng có cần ghi nhãn hàng hóa không?',
#  '8516': 'Thực hiện thủ tục đề nghị cấp Giấy phép vận tải đường bộ quốc tế ASEAN, đơn vị kinh doanh vận tải phải nộp lệ phí bao nhiêu?',
#  '154124': 'Đài Tiếng nói Việt Nam có chức năng như thế nào theo quy định hiện nay?',
#  '46538': 'Thỏa thuận chia tài sản thuộc sở hữu chung của các thành viên trong gia đình phải dược công chứng trong thời hạn bao nhiêu ngày?',
#  '6961': 'Trung tâm phối hợp tìm kiếm cứu nạn hàng không khi nhận được thông tin về tàu bay đang khẩn nguy thì phải làm gì?',
#  '95051': 'Điều kiện lưu hành đối với trang thiết bị y tế được quy định như thế nào?',
#  '69253': 'Quyết định thu hồi Giấy chứng nhận đăng ký hộ kinh doanh bị hủy bỏ trong trường hợp nào?',
#  '137448': 'Việc kiểm tra, đánh giá an toàn đập, hồ chứa nước khi khai thác đập, hồ chứa nước được quy định như thế nào?',
#  '80121': 'Đơn vị máu, chế phẩm máu đạt tiêu chuẩn khi đáp ứng quy định nào?',
#  '88742': 'Thủ tục thông qua hợp đồng chế tạo thiết bị phụ nhà máy nhiệt điện được thực hiện như thế nào?',
#  '94899': 'Học sinh 13 tuổi có thể bị đưa vào trường giáo dưỡng khi có dấu hiệu của tội phạm đặc biệt nghiêm trọng hay không?',
#  '151362': 'Người phụ trách trinh sát đám cháy phải nắm vững các nội dung nào khi thực hiện nhiệm vụ của mình?',
#  '62782': 'Đề xuất bãi bỏ một phần của 04 văn bản quy phạm pháp luật nào?',
#  '21083': 'Phiếu lý lịch tư pháp bao gồm những loại nào?',
#  '59633': 'Mức hưởng bảo hiểm xã hội một lần đối với người lao động làm việc theo hợp đồng lao động xác định thời hạn cụ thể như thế nào?',
#  '140346': 'Trách nhiệm công khai thông tin trang thiết bị y tế được quy định thế nào?',
#  '14201': 'Thế nào là bảo hiểm xã hội?',
#  '80089': 'Cán bộ, công chức, viên chức đe dọa công dân thực hiện dân chủ ở cơ sở bị xử lý như thế nào?',
#  '52851': 'Người đã chấp hành xong quyết định xử phạt vi phạm hành chính có được xuất cảnh không?',
#  '64688': 'Liên lạc dữ liệu giữa tổ lái và kiểm soát viên không lưu được viết tắt là gì?',
#  '49316': 'Nhà nước sẽ hỗ trợ những khoản nào khi thu hồi đất?',
#  '130028': 'Ban chấp hành công đoàn các cấp có nhiệm vụ, quyền hạn gì?',
#  '2704': 'Xây bảng quảng cáo dọc tuyến đường cao tốc TPHCM - Long Thành - Dầu Giây vượt quá kích thước cho phép sẽ bị xử phạt như thế nào?',
#  '93457': 'Ở khu vực nông thôn giá nước sạch hiện nay được quy định là bao nhiêu?',
#  '112772': 'Hội Tin học Việt Nam chịu sự quản lý nhà nước của cơ quan nào?',
#  '137084': 'Thu hồi đất vì mục đích quốc phòng an ninh là gì?',
#  '31771': 'Chứng chỉ hành nghề xây dựng do cơ quan nào cấp?',
#  '119842': 'Trong phẫu thuật sửa sẹo bọng sau phẫu thuật glôcôm có thể có các biến chứng gì?',
#  ...}

# %%
from typing import Dict, List, Tuple, Set
import re
from dataclasses import dataclass
import spacy
from transformers import AutoTokenizer, AutoModelForTokenClassification
import torch

@dataclass
class LegalEntity:
    text: str
    label: str
    start: int
    end: int

class LegalNER:
    def __init__(self):
        # Load mô hình NER tiếng Việt (VnCoreNLP hoặc PhoBERT-NER)
        self.tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base")
        self.model = AutoModelForTokenClassification.from_pretrained("vinai/phobert-base")
        
        # Định nghĩa các label cho legal domain
        self.legal_labels = {
            'LAW': ['luật', 'nghị định', 'thông tư', 'quyết định'],
            'ORGANIZATION': ['bộ', 'sở', 'ủy ban', 'tòa án'],
            'POSITION': ['chủ tịch', 'giám đốc', 'trưởng phòng'],
            'MONEY': ['đồng', 'triệu', 'tỷ', 'USD'],
            'TIME': ['ngày', 'tháng', 'năm', 'kỳ hạn'],
            'PENALTY': ['phạt', 'xử phạt', 'chế tài'],
        }
        
        # Compile regex patterns
        self.patterns = self._compile_patterns()

    def _compile_patterns(self) -> Dict[str, List[re.Pattern]]:
        """Compile regex patterns cho mỗi loại entity"""
        patterns = {}
        for label, keywords in self.legal_labels.items():
            patterns[label] = [
                re.compile(rf'\b{keyword}\b[\s\w]+', re.IGNORECASE) 
                for keyword in keywords
            ]
        return patterns

    def extract_entities(self, text: str) -> List[LegalEntity]:
        """Trích xuất legal entities từ text sử dụng kết hợp rule-based và model-based"""
        entities = []
        
        # 1. Rule-based extraction using patterns
        for label, patterns in self.patterns.items():
            for pattern in patterns:
                for match in pattern.finditer(text):
                    entities.append(LegalEntity(
                        text=match.group().strip(),
                        label=label,
                        start=match.start(),
                        end=match.end()
                    ))
        
        # 2. Model-based extraction using PhoBERT-NER
        inputs = self.tokenizer(text, return_tensors="pt", truncation=True)
        outputs = self.model(**inputs)
        predictions = torch.argmax(outputs.logits, dim=2)
        
        tokens = self.tokenizer.convert_ids_to_tokens(inputs["input_ids"][0])
        current_entity = None
        
        for idx, (token, pred) in enumerate(zip(tokens, predictions[0])):
            if pred in self.model.config.label2id:
                label = self.model.config.id2label[pred.item()]
                if label.startswith("B-"):  # Beginning of entity
                    if current_entity:
                        entities.append(current_entity)
                    current_entity = LegalEntity(
                        text=token,
                        label=label[2:],
                        start=idx,
                        end=idx
                    )
                elif label.startswith("I-") and current_entity:  # Inside entity
                    current_entity.text += f" {token}"
                    current_entity.end = idx
        
        if current_entity:
            entities.append(current_entity)
        
        return self._merge_overlapping_entities(entities)

    def _merge_overlapping_entities(self, entities: List[LegalEntity]) -> List[LegalEntity]:
        """Gộp các entity chồng chéo"""
        if not entities:
            return []
            
        entities.sort(key=lambda x: (x.start, -x.end))
        merged = [entities[0]]
        
        for current in entities[1:]:
            previous = merged[-1]
            
            if current.start <= previous.end:
                # Nếu cùng label và có overlap, merge lại
                if current.label == previous.label:
                    previous.end = max(previous.end, current.end)
                    previous.text = previous.text + " " + current.text
            else:
                merged.append(current)
                
        return merged

class LegalQASystem:
    def __init__(self):
        self.ner = LegalNER()
        
    def process_query(self, query: str) -> Dict[str, List[LegalEntity]]:
        """Xử lý câu query và trích xuất entities"""
        query_entities = self.ner.extract_entities(query)
        return self._categorize_entities(query_entities)
    
    def process_document(self, doc_text: str) -> Dict[str, List[LegalEntity]]:
        """Xử lý văn bản pháp luật và trích xuất entities"""
        doc_entities = self.ner.extract_entities(doc_text)
        return self._categorize_entities(doc_entities)
    
    def _categorize_entities(self, entities: List[LegalEntity]) -> Dict[str, List[LegalEntity]]:
        """Phân loại entities theo label"""
        categorized = {}
        for entity in entities:
            if entity.label not in categorized:
                categorized[entity.label] = []
            categorized[entity.label].append(entity)
        return categorized
    
    def calculate_entity_similarity(
        self,
        query_entities: Dict[str, List[LegalEntity]],
        doc_entities: Dict[str, List[LegalEntity]]
    ) -> float:
        """Tính độ tương đồng giữa entities của query và document"""
        total_score = 0
        total_weight = 0
        
        # Định nghĩa trọng số cho từng loại entity
        weights = {
            'LAW': 1.0,
            'ORGANIZATION': 0.8,
            'POSITION': 0.6,
            'MONEY': 0.7,
            'TIME': 0.5,
            'PENALTY': 0.9
        }
        
        for label in set(query_entities.keys()) & set(doc_entities.keys()):
            query_texts = {e.text.lower() for e in query_entities[label]}
            doc_texts = {e.text.lower() for e in doc_entities[label]}
            
            # Tính Jaccard similarity cho mỗi loại entity
            intersection = len(query_texts & doc_texts)
            union = len(query_texts | doc_texts)
            if union > 0:
                score = intersection / union
                total_score += score * weights[label]
                total_weight += weights[label]
        
        return total_score / total_weight if total_weight > 0 else 0.0
    
    def find_relevant_documents(
        self,
        query: str,
        documents: Dict[str, str],
        top_k: int = 3
    ) -> List[Tuple[str, float]]:
        """Tìm văn bản liên quan dựa trên entity matching"""
        query_entities = self.process_query(query)
        
        scores = []
        for doc_id, doc_text in documents.items():
            doc_entities = self.process_document(doc_text)
            similarity = self.calculate_entity_similarity(query_entities, doc_entities)
            scores.append((doc_id, similarity))
        
        # Sort by similarity score
        scores.sort(key=lambda x: x[1], reverse=True)
        return scores[:top_k]

    def answer_query(
        self,
        query: str,
        documents: Dict[str, str]
    ) -> Dict[str, any]:
        """Trả lời câu hỏi dựa trên entity matching"""
        # Xử lý query
        query_entities = self.process_query(query)
        
        # Tìm documents liên quan
        relevant_docs = self.find_relevant_documents(query, documents)
        
        # Lấy document có score cao nhất
        best_doc_id, score = relevant_docs[0]
        
        return {
            'query_entities': query_entities,
            'relevant_document': documents[best_doc_id],
            'confidence_score': score,
            'matched_entities': self.process_document(documents[best_doc_id])
        }

# Example usage
if __name__ == "__main__":
    qa_system = LegalQASystem()
    
    # Sample data
    documents = {
        '14201': """
        Bảo hiểm xã hội là chế độ bảo đảm thay thế hoặc bù đắp một phần thu nhập của 
        người lao động khi họ bị giảm hoặc mất thu nhập do ốm đau, thai sản, tai nạn
        lao động, bệnh nghề nghiệp, hết tuổi lao động hoặc chết, trên cơ sở đóng vào 
        quỹ bảo hiểm xã hội.
        """,
        '59633': """
        Theo Điều 8 Nghị định số 115/2015/NĐ-CP ngày 11/11/2015, người lao động làm việc 
        theo hợp đồng lao động xác định thời hạn được hưởng bảo hiểm xã hội một lần với 
        mức hưởng bằng 1,5 tháng mức bình quân tiền lương tháng đóng bảo hiểm xã hội cho 
        những năm đóng trước năm 2014.
        """
    }
    
    # Process a query
    query = "Thế nào là bảo hiểm xã hội?"
    result = qa_system.answer_query(query, documents)
    
    print("Query entities:", result['query_entities'])
    print("Matched entities:", result['matched_entities'])
    print("Confidence score:", result['confidence_score'])
